# %%
import json
from pathlib import Path
from sklearn.cluster import KMeans
import numpy as np

# %%
# TODO: Load metadata
metadata_path = Path("../storage/eo_metadata.json")

with open(metadata_path, "r") as f:
    metadata = json.load(f)

print(f"Loaded {len(metadata)} products")
print(metadata[0])
# Out:
# Loaded 200 products
# {'eo_product_id': 'EO-001', 'image_path': 'storage/object_store/original/EO-001.png', 'enhanced_path': 'storage/object_store/enhanced/EO-001-enhanced.png', 'brightness': 0.19477467256433822, 'contrast': 0.21783494271782936, 'quality_score': 0.20630480764108378, 'is_visible': True, 'priority': 3}

# %%
# TODO: implement clustering
def run_clustering(metadata, K=3):
    features = np.array([[item["brightness"], item["contrast"]] for item in metadata])

    kmeans = KMeans(n_clusters=K, random_state=42)
    labels = kmeans.fit_predict(features)

    for i, item in enumerate(metadata):
        item["cluster"] = int(labels[i])

    return metadata

metadata = run_clustering(metadata)
print(metadata[0])
# Out:
# {'eo_product_id': 'EO-001', 'image_path': 'storage/object_store/original/EO-001.png', 'enhanced_path': 'storage/object_store/enhanced/EO-001-enhanced.png', 'brightness': 0.19477467256433822, 'contrast': 0.21783494271782936, 'quality_score': 0.20630480764108378, 'is_visible': True, 'priority': 3, 'cluster': 1}
